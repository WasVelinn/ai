# %%
import numpy as np
from tensorflow.keras.models import Sequential # 모델 객체 생성
from tensorflow.keras.layers import Dense, Input # 모델 layer 쌓을 때 필요한 함수
import matplotlib.pyplot as plt

# %%
# 1. dataset
x_data = np.array([[0,0], [0,1], [1,0], [1,1]])
y_data = np.array([[0],[1],[1],[0]])

# 2. 모델 구성
model = Sequential()
# mode1.add(Input(shape=2))
model.add(Dense(units = 10,
                 input_dim = 2,
                 activation = 'relu' 
                 ))
model.add(Dense(units = 20, activation = 'relu')) # 은닉층(hidden layer)에서는 input_shape를 쓰지 않음.
model.add(Dense(units = 10, activation = 'relu'))
model.add(Dense(units = 1, activation = 'sigmoid'))

# 3. 모델 학습과정 설정
# model.compile(loss = 'mse', optimizer = 'adam', metrics = ['mae']) # 회귀식에서 학습과정 설정
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['binary_accuracy'])
# model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy']) # 다중분류

# %%
# 4. 학습
hist = model.fit(x_data, y_data, epochs = 200, verbose = 2)
# Out:
# Epoch 1/200
# 1/1 - 0s - loss: 0.7088 - binary_accuracy: 0.5000 - 417ms/epoch - 417ms/step
# Epoch 2/200
# 1/1 - 0s - loss: 0.7073 - binary_accuracy: 0.5000 - 14ms/epoch - 14ms/step
# Epoch 3/200
# 1/1 - 0s - loss: 0.7059 - binary_accuracy: 0.5000 - 7ms/epoch - 7ms/step
# Epoch 4/200
# 1/1 - 0s - loss: 0.7044 - binary_accuracy: 0.5000 - 14ms/epoch - 14ms/step
# Epoch 5/200
# 1/1 - 0s - loss: 0.7030 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 6/200
# 1/1 - 0s - loss: 0.7017 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 7/200
# 1/1 - 0s - loss: 0.7004 - binary_accuracy: 0.5000 - 17ms/epoch - 17ms/step
# Epoch 8/200
# 1/1 - 0s - loss: 0.6992 - binary_accuracy: 0.5000 - 17ms/epoch - 17ms/step
# Epoch 9/200
# 1/1 - 0s - loss: 0.6979 - binary_accuracy: 0.5000 - 17ms/epoch - 17ms/step
# Epoch 10/200
# 1/1 - 0s - loss: 0.6966 - binary_accuracy: 0.5000 - 16ms/epoch - 16ms/step
# Epoch 11/200
# 1/1 - 0s - loss: 0.6954 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 12/200
# 1/1 - 0s - loss: 0.6941 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 13/200
# 1/1 - 0s - loss: 0.6928 - binary_accuracy: 0.5000 - 17ms/epoch - 17ms/step
# Epoch 14/200
# 1/1 - 0s - loss: 0.6916 - binary_accuracy: 0.5000 - 16ms/epoch - 16ms/step
# Epoch 15/200
# 1/1 - 0s - loss: 0.6905 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 16/200
# 1/1 - 0s - loss: 0.6895 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 17/200
# 1/1 - 0s - loss: 0.6890 - binary_accuracy: 0.5000 - 17ms/epoch - 17ms/step
# Epoch 18/200
# 1/1 - 0s - loss: 0.6885 - binary_accuracy: 0.5000 - 17ms/epoch - 17ms/step
# Epoch 19/200
# 1/1 - 0s - loss: 0.6880 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 20/200
# 1/1 - 0s - loss: 0.6874 - binary_accuracy: 0.5000 - 17ms/epoch - 17ms/step
# Epoch 21/200
# 1/1 - 0s - loss: 0.6867 - binary_accuracy: 0.5000 - 16ms/epoch - 16ms/step
# Epoch 22/200
# 1/1 - 0s - loss: 0.6860 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 23/200
# 1/1 - 0s - loss: 0.6852 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 24/200
# 1/1 - 0s - loss: 0.6844 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 25/200
# 1/1 - 0s - loss: 0.6836 - binary_accuracy: 0.5000 - 0s/epoch - 0s/step
# Epoch 26/200
# 1/1 - 0s - loss: 0.6828 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 27/200
# 1/1 - 0s - loss: 0.6819 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 28/200
# 1/1 - 0s - loss: 0.6811 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 29/200
# 1/1 - 0s - loss: 0.6803 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 30/200
# 1/1 - 0s - loss: 0.6797 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 31/200
# 1/1 - 0s - loss: 0.6791 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 32/200
# 1/1 - 0s - loss: 0.6785 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 33/200
# 1/1 - 0s - loss: 0.6779 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 34/200
# 1/1 - 0s - loss: 0.6772 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 35/200
# 1/1 - 0s - loss: 0.6765 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 36/200
# 1/1 - 0s - loss: 0.6758 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 37/200
# 1/1 - 0s - loss: 0.6751 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 38/200
# 1/1 - 0s - loss: 0.6746 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 39/200
# 1/1 - 0s - loss: 0.6741 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 40/200
# 1/1 - 0s - loss: 0.6735 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 41/200
# 1/1 - 0s - loss: 0.6729 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 42/200
# 1/1 - 0s - loss: 0.6722 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 43/200
# 1/1 - 0s - loss: 0.6716 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 44/200
# 1/1 - 0s - loss: 0.6709 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 45/200
# 1/1 - 0s - loss: 0.6702 - binary_accuracy: 0.7500 - 19ms/epoch - 19ms/step
# Epoch 46/200
# 1/1 - 0s - loss: 0.6696 - binary_accuracy: 0.7500 - 14ms/epoch - 14ms/step
# Epoch 47/200
# 1/1 - 0s - loss: 0.6688 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 48/200
# 1/1 - 0s - loss: 0.6682 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 49/200
# 1/1 - 0s - loss: 0.6675 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 50/200
# 1/1 - 0s - loss: 0.6669 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 51/200
# 1/1 - 0s - loss: 0.6663 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 52/200
# 1/1 - 0s - loss: 0.6657 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 53/200
# 1/1 - 0s - loss: 0.6651 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 54/200
# 1/1 - 0s - loss: 0.6644 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 55/200
# 1/1 - 0s - loss: 0.6637 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 56/200
# 1/1 - 0s - loss: 0.6631 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 57/200
# 1/1 - 0s - loss: 0.6624 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 58/200
# 1/1 - 0s - loss: 0.6617 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 59/200
# 1/1 - 0s - loss: 0.6610 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 60/200
# 1/1 - 0s - loss: 0.6604 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 61/200
# 1/1 - 0s - loss: 0.6597 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 62/200
# 1/1 - 0s - loss: 0.6591 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 63/200
# 1/1 - 0s - loss: 0.6584 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 64/200
# 1/1 - 0s - loss: 0.6577 - binary_accuracy: 0.7500 - 22ms/epoch - 22ms/step
# Epoch 65/200
# 1/1 - 0s - loss: 0.6570 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 66/200
# 1/1 - 0s - loss: 0.6563 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 67/200
# 1/1 - 0s - loss: 0.6556 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 68/200
# 1/1 - 0s - loss: 0.6549 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 69/200
# 1/1 - 0s - loss: 0.6542 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 70/200
# 1/1 - 0s - loss: 0.6535 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 71/200
# 1/1 - 0s - loss: 0.6528 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 72/200
# 1/1 - 0s - loss: 0.6520 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 73/200
# 1/1 - 0s - loss: 0.6512 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 74/200
# 1/1 - 0s - loss: 0.6505 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 75/200
# 1/1 - 0s - loss: 0.6497 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 76/200
# 1/1 - 0s - loss: 0.6490 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 77/200
# 1/1 - 0s - loss: 0.6482 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 78/200
# 1/1 - 0s - loss: 0.6474 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 79/200
# 1/1 - 0s - loss: 0.6467 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 80/200
# 1/1 - 0s - loss: 0.6458 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 81/200
# 1/1 - 0s - loss: 0.6450 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 82/200
# 1/1 - 0s - loss: 0.6442 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 83/200
# 1/1 - 0s - loss: 0.6433 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 84/200
# 1/1 - 0s - loss: 0.6425 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 85/200
# 1/1 - 0s - loss: 0.6416 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 86/200
# 1/1 - 0s - loss: 0.6408 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 87/200
# 1/1 - 0s - loss: 0.6399 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 88/200
# 1/1 - 0s - loss: 0.6390 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 89/200
# 1/1 - 0s - loss: 0.6382 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 90/200
# 1/1 - 0s - loss: 0.6373 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 91/200
# 1/1 - 0s - loss: 0.6363 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 92/200
# 1/1 - 0s - loss: 0.6354 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 93/200
# 1/1 - 0s - loss: 0.6345 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 94/200
# 1/1 - 0s - loss: 0.6335 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 95/200
# 1/1 - 0s - loss: 0.6325 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 96/200
# 1/1 - 0s - loss: 0.6315 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 97/200
# 1/1 - 0s - loss: 0.6305 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 98/200
# 1/1 - 0s - loss: 0.6295 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 99/200
# 1/1 - 0s - loss: 0.6285 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 100/200
# 1/1 - 0s - loss: 0.6274 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 101/200
# 1/1 - 0s - loss: 0.6264 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 102/200
# 1/1 - 0s - loss: 0.6254 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 103/200
# 1/1 - 0s - loss: 0.6243 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 104/200
# 1/1 - 0s - loss: 0.6232 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 105/200
# 1/1 - 0s - loss: 0.6221 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 106/200
# 1/1 - 0s - loss: 0.6210 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 107/200
# 1/1 - 0s - loss: 0.6198 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 108/200
# 1/1 - 0s - loss: 0.6187 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 109/200
# 1/1 - 0s - loss: 0.6175 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 110/200
# 1/1 - 0s - loss: 0.6163 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 111/200
# 1/1 - 0s - loss: 0.6151 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 112/200
# 1/1 - 0s - loss: 0.6140 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 113/200
# 1/1 - 0s - loss: 0.6127 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 114/200
# 1/1 - 0s - loss: 0.6112 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 115/200
# 1/1 - 0s - loss: 0.6098 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 116/200
# 1/1 - 0s - loss: 0.6085 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 117/200
# 1/1 - 0s - loss: 0.6070 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 118/200
# 1/1 - 0s - loss: 0.6055 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 119/200
# 1/1 - 0s - loss: 0.6039 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 120/200
# 1/1 - 0s - loss: 0.6023 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 121/200
# 1/1 - 0s - loss: 0.6006 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 122/200
# 1/1 - 0s - loss: 0.5988 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 123/200
# 1/1 - 0s - loss: 0.5971 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 124/200
# 1/1 - 0s - loss: 0.5953 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 125/200
# 1/1 - 0s - loss: 0.5934 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 126/200
# 1/1 - 0s - loss: 0.5914 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 127/200
# 1/1 - 0s - loss: 0.5896 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 128/200
# 1/1 - 0s - loss: 0.5878 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 129/200
# 1/1 - 0s - loss: 0.5860 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 130/200
# 1/1 - 0s - loss: 0.5841 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 131/200
# 1/1 - 0s - loss: 0.5822 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 132/200
# 1/1 - 0s - loss: 0.5803 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 133/200
# 1/1 - 0s - loss: 0.5782 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 134/200
# 1/1 - 0s - loss: 0.5761 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 135/200
# 1/1 - 0s - loss: 0.5739 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 136/200
# 1/1 - 0s - loss: 0.5718 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 137/200
# 1/1 - 0s - loss: 0.5697 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 138/200
# 1/1 - 0s - loss: 0.5677 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 139/200
# 1/1 - 0s - loss: 0.5656 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 140/200
# 1/1 - 0s - loss: 0.5634 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 141/200
# 1/1 - 0s - loss: 0.5613 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 142/200
# 1/1 - 0s - loss: 0.5591 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 143/200
# 1/1 - 0s - loss: 0.5569 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 144/200
# 1/1 - 0s - loss: 0.5548 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 145/200
# 1/1 - 0s - loss: 0.5525 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 146/200
# 1/1 - 0s - loss: 0.5502 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 147/200
# 1/1 - 0s - loss: 0.5479 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 148/200
# 1/1 - 0s - loss: 0.5455 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 149/200
# 1/1 - 0s - loss: 0.5432 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 150/200
# 1/1 - 0s - loss: 0.5408 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 151/200
# 1/1 - 0s - loss: 0.5383 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 152/200
# 1/1 - 0s - loss: 0.5360 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 153/200
# 1/1 - 0s - loss: 0.5336 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 154/200
# 1/1 - 0s - loss: 0.5312 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 155/200
# 1/1 - 0s - loss: 0.5287 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 156/200
# 1/1 - 0s - loss: 0.5263 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 157/200
# 1/1 - 0s - loss: 0.5237 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 158/200
# 1/1 - 0s - loss: 0.5213 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 159/200
# 1/1 - 0s - loss: 0.5187 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 160/200
# 1/1 - 0s - loss: 0.5160 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 161/200
# 1/1 - 0s - loss: 0.5134 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 162/200
# 1/1 - 0s - loss: 0.5109 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 163/200
# 1/1 - 0s - loss: 0.5083 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 164/200
# 1/1 - 0s - loss: 0.5056 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 165/200
# 1/1 - 0s - loss: 0.5031 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 166/200
# 1/1 - 0s - loss: 0.5003 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 167/200
# 1/1 - 0s - loss: 0.4976 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 168/200
# 1/1 - 0s - loss: 0.4949 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 169/200
# 1/1 - 0s - loss: 0.4921 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 170/200
# 1/1 - 0s - loss: 0.4894 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 171/200
# 1/1 - 0s - loss: 0.4866 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 172/200
# 1/1 - 0s - loss: 0.4838 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 173/200
# 1/1 - 0s - loss: 0.4809 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 174/200
# 1/1 - 0s - loss: 0.4780 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 175/200
# 1/1 - 0s - loss: 0.4752 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 176/200
# 1/1 - 0s - loss: 0.4723 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 177/200
# 1/1 - 0s - loss: 0.4694 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 178/200
# 1/1 - 0s - loss: 0.4665 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 179/200
# 1/1 - 0s - loss: 0.4636 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 180/200
# 1/1 - 0s - loss: 0.4606 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 181/200
# 1/1 - 0s - loss: 0.4576 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 182/200
# 1/1 - 0s - loss: 0.4546 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 183/200
# 1/1 - 0s - loss: 0.4516 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 184/200
# 1/1 - 0s - loss: 0.4486 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 185/200
# 1/1 - 0s - loss: 0.4455 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 186/200
# 1/1 - 0s - loss: 0.4425 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 187/200
# 1/1 - 0s - loss: 0.4394 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 188/200
# 1/1 - 0s - loss: 0.4364 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 189/200
# 1/1 - 0s - loss: 0.4333 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 190/200
# 1/1 - 0s - loss: 0.4302 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 191/200
# 1/1 - 0s - loss: 0.4271 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 192/200
# 1/1 - 0s - loss: 0.4238 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 193/200
# 1/1 - 0s - loss: 0.4208 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 194/200
# 1/1 - 0s - loss: 0.4178 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 195/200
# 1/1 - 0s - loss: 0.4145 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 196/200
# 1/1 - 0s - loss: 0.4113 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 197/200
# 1/1 - 0s - loss: 0.4081 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 198/200
# 1/1 - 0s - loss: 0.4049 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 199/200
# 1/1 - 0s - loss: 0.4018 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 200/200
# 1/1 - 0s - loss: 0.3986 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step

# %%
# 5. 학습과정 보기 및 평가
hist.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy'])

# %%
fig, loss_ax = plt.subplots(figsize=(10,5))
loss_ax.plot(hist.history['loss'], 'b', label = 'loss')
acc_ax = loss_ax.twinx() # loss_ax와 x축을 공유하는 acc_ax
acc_ax.plot(hist.history['binary_accuracy'], 'r', label = 'binary_accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('binary_accuracy')

loss_ax.legend(loc = 'center right')
acc_ax.legend(bbox_to_anchor = (1.0, 0.65))

# %%
# 모델 평가하기
score = model.evaluate(x_data, y_data)
score
# Out:
# 1/1 [==============================] - 0s 156ms/step - loss: 0.3954 - binary_accuracy: 1.0000
# [0.3953539729118347, 1.0]

# %%
# 예측
model.predict(np.array([[0, 1]])).round()
# Out:
# 1/1 [==============================] - 0s 20ms/step
# array([[1.]], dtype=float32)

# %%
# 독립변수 2개(0 0, 0 1, 1 0, 1 1)를 입력받아 예측값을 출력(종료는 수를 1개만 입력할 때)
while True :
    input_str = input('space로 분리해서 0또는 1을 2개 입력(한개만 입력하면 종료됩니다.') # '0', '1'
    # '   0     1   ' -> '0  1' => '0', '1'
    input_list = input_str.strip().split()
    input_nums = list(map(int, input_list)) # [0, 1]
    if len(input_nums)==1:
        print('데이터를 하나만 입력할 경우 종료됩니다.')
        break
    if all(x in [0,1] for x in input_nums) : # 0과 1만 입력한 경우
        input_data = np.array([input_nums[:2]]).reshape(-1, 2)
        print('입력 값 :', input_nums[0], input_nums[1])
        print('예측 값 :', int(model.predict(input_data).round()))
    else :
        print('유효하지 않은 값')
# Out:
# space로 분리해서 0또는 1을 2개 입력(한개만 입력하면 종료됩니다.0 2 1
# 유효하지 않은 값
# space로 분리해서 0또는 1을 2개 입력(한개만 입력하면 종료됩니다.1 0
# 입력 값 : 1 0
# 1/1 [==============================] - 0s 20ms/step
# 예측 값 : 1
# space로 분리해서 0또는 1을 2개 입력(한개만 입력하면 종료됩니다.1 0 0 0 0 0
# 입력 값 : 1 0
# 1/1 [==============================] - 0s 18ms/step
# 예측 값 : 1
# space로 분리해서 0또는 1을 2개 입력(한개만 입력하면 종료됩니다.니애미
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 6
#       4 # '   0     1   ' -> '0  1' => '0', '1'
#       5 input_list = input_str.strip().split()
# ----> 6 input_nums = list(map(int, input_list)) # [0, 1]
#       7 if len(input_nums)==1:
#       8     print('데이터를 하나만 입력할 경우 종료됩니다.')
#
# ValueError: invalid literal for int() with base 10: '니애미'

# %% [markdown]
# # 2. AND

# %%
# 1. dataset
x_data = np.array([[0,0], [0,1], [1,0], [1,1]])
y_data = np.array([[0],[0],[0],[1]])
# 2. 모델 구성
model = Sequential()
# mode1.add(Input(shape=2))
model.add(Dense(units = 10,
                 input_dim = 2,
                 activation = 'relu' 
                 ))
model.add(Dense(units = 20, activation = 'relu')) # 은닉층(hidden layer)에서는 input_shape를 쓰지 않음.
model.add(Dense(units = 10, activation = 'relu'))
model.add(Dense(units = 1, activation = 'sigmoid'))
# 3. 모델학습과정(이진분류)
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['binary_accuracy'])
# 4. 학습
hist = model.fit(x_data, y_data, epochs = 200, verbose = 2)
# 5. 학습과정 살펴보기 및 평가
score = model.evaluate(x_data, y_data)
score
# 6. 예측하기 : np.array([[0,1]])를 예측하기
model.predict(np.array([[0,1]])).round()
# Out:
# Epoch 1/200
# 1/1 - 0s - loss: 0.7011 - binary_accuracy: 0.7500 - 427ms/epoch - 427ms/step
# Epoch 2/200
# 1/1 - 0s - loss: 0.6966 - binary_accuracy: 0.7500 - 8ms/epoch - 8ms/step
# Epoch 3/200
# 1/1 - 0s - loss: 0.6921 - binary_accuracy: 0.7500 - 11ms/epoch - 11ms/step
# Epoch 4/200
# 1/1 - 0s - loss: 0.6881 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 5/200
# 1/1 - 0s - loss: 0.6842 - binary_accuracy: 0.7500 - 1ms/epoch - 1ms/step
# Epoch 6/200
# 1/1 - 0s - loss: 0.6803 - binary_accuracy: 0.7500 - 15ms/epoch - 15ms/step
# Epoch 7/200
# 1/1 - 0s - loss: 0.6765 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 8/200
# 1/1 - 0s - loss: 0.6733 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 9/200
# 1/1 - 0s - loss: 0.6700 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 10/200
# 1/1 - 0s - loss: 0.6667 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 11/200
# 1/1 - 0s - loss: 0.6634 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 12/200
# 1/1 - 0s - loss: 0.6601 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 13/200
# 1/1 - 0s - loss: 0.6569 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 14/200
# 1/1 - 0s - loss: 0.6542 - binary_accuracy: 0.7500 - 1ms/epoch - 1ms/step
# Epoch 15/200
# 1/1 - 0s - loss: 0.6518 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 16/200
# 1/1 - 0s - loss: 0.6491 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 17/200
# 1/1 - 0s - loss: 0.6469 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 18/200
# 1/1 - 0s - loss: 0.6445 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 19/200
# 1/1 - 0s - loss: 0.6420 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 20/200
# 1/1 - 0s - loss: 0.6393 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 21/200
# 1/1 - 0s - loss: 0.6367 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 22/200
# 1/1 - 0s - loss: 0.6344 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 23/200
# 1/1 - 0s - loss: 0.6320 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 24/200
# 1/1 - 0s - loss: 0.6295 - binary_accuracy: 0.7500 - 17ms/epoch - 17ms/step
# Epoch 25/200
# 1/1 - 0s - loss: 0.6268 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 26/200
# 1/1 - 0s - loss: 0.6241 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 27/200
# 1/1 - 0s - loss: 0.6215 - binary_accuracy: 0.7500 - 0s/epoch - 0s/step
# Epoch 28/200
# 1/1 - 0s - loss: 0.6189 - binary_accuracy: 0.7500 - 16ms/epoch - 16ms/step
# Epoch 29/200
# 1/1 - 0s - loss: 0.6166 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 30/200
# 1/1 - 0s - loss: 0.6141 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 31/200
# 1/1 - 0s - loss: 0.6116 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 32/200
# 1/1 - 0s - loss: 0.6092 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 33/200
# 1/1 - 0s - loss: 0.6066 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 34/200
# 1/1 - 0s - loss: 0.6039 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 35/200
# 1/1 - 0s - loss: 0.6011 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 36/200
# 1/1 - 0s - loss: 0.5984 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 37/200
# 1/1 - 0s - loss: 0.5958 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 38/200
# 1/1 - 0s - loss: 0.5931 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 39/200
# 1/1 - 0s - loss: 0.5903 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 40/200
# 1/1 - 0s - loss: 0.5876 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 41/200
# 1/1 - 0s - loss: 0.5847 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 42/200
# 1/1 - 0s - loss: 0.5818 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 43/200
# 1/1 - 0s - loss: 0.5789 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 44/200
# 1/1 - 0s - loss: 0.5761 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 45/200
# 1/1 - 0s - loss: 0.5732 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 46/200
# 1/1 - 0s - loss: 0.5699 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 47/200
# 1/1 - 0s - loss: 0.5665 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 48/200
# 1/1 - 0s - loss: 0.5630 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 49/200
# 1/1 - 0s - loss: 0.5601 - binary_accuracy: 1.0000 - 17ms/epoch - 17ms/step
# Epoch 50/200
# 1/1 - 0s - loss: 0.5572 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 51/200
# 1/1 - 0s - loss: 0.5540 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 52/200
# 1/1 - 0s - loss: 0.5507 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 53/200
# 1/1 - 0s - loss: 0.5474 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 54/200
# 1/1 - 0s - loss: 0.5441 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 55/200
# 1/1 - 0s - loss: 0.5408 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 56/200
# 1/1 - 0s - loss: 0.5373 - binary_accuracy: 1.0000 - 21ms/epoch - 21ms/step
# Epoch 57/200
# 1/1 - 0s - loss: 0.5337 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 58/200
# 1/1 - 0s - loss: 0.5303 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 59/200
# 1/1 - 0s - loss: 0.5270 - binary_accuracy: 1.0000 - 25ms/epoch - 25ms/step
# Epoch 60/200
# 1/1 - 0s - loss: 0.5234 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 61/200
# 1/1 - 0s - loss: 0.5195 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 62/200
# 1/1 - 0s - loss: 0.5155 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 63/200
# 1/1 - 0s - loss: 0.5116 - binary_accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 64/200
# 1/1 - 0s - loss: 0.5077 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 65/200
# 1/1 - 0s - loss: 0.5037 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 66/200
# 1/1 - 0s - loss: 0.4995 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 67/200
# 1/1 - 0s - loss: 0.4952 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 68/200
# 1/1 - 0s - loss: 0.4909 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 69/200
# 1/1 - 0s - loss: 0.4866 - binary_accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 70/200
# 1/1 - 0s - loss: 0.4822 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 71/200
# 1/1 - 0s - loss: 0.4778 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 72/200
# 1/1 - 0s - loss: 0.4734 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 73/200
# 1/1 - 0s - loss: 0.4690 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 74/200
# 1/1 - 0s - loss: 0.4644 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 75/200
# 1/1 - 0s - loss: 0.4600 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 76/200
# 1/1 - 0s - loss: 0.4553 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 77/200
# 1/1 - 0s - loss: 0.4506 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 78/200
# 1/1 - 0s - loss: 0.4460 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 79/200
# 1/1 - 0s - loss: 0.4413 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 80/200
# 1/1 - 0s - loss: 0.4365 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 81/200
# 1/1 - 0s - loss: 0.4316 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 82/200
# 1/1 - 0s - loss: 0.4267 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 83/200
# 1/1 - 0s - loss: 0.4220 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 84/200
# 1/1 - 0s - loss: 0.4171 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 85/200
# 1/1 - 0s - loss: 0.4122 - binary_accuracy: 1.0000 - 508us/epoch - 508us/step
# Epoch 86/200
# 1/1 - 0s - loss: 0.4073 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 87/200
# 1/1 - 0s - loss: 0.4023 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 88/200
# 1/1 - 0s - loss: 0.3973 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 89/200
# 1/1 - 0s - loss: 0.3924 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 90/200
# 1/1 - 0s - loss: 0.3874 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 91/200
# 1/1 - 0s - loss: 0.3823 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 92/200
# 1/1 - 0s - loss: 0.3773 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 93/200
# 1/1 - 0s - loss: 0.3722 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 94/200
# 1/1 - 0s - loss: 0.3672 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 95/200
# 1/1 - 0s - loss: 0.3621 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 96/200
# 1/1 - 0s - loss: 0.3571 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 97/200
# 1/1 - 0s - loss: 0.3519 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 98/200
# 1/1 - 0s - loss: 0.3468 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 99/200
# 1/1 - 0s - loss: 0.3417 - binary_accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 100/200
# 1/1 - 0s - loss: 0.3367 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 101/200
# 1/1 - 0s - loss: 0.3317 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 102/200
# 1/1 - 0s - loss: 0.3267 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 103/200
# 1/1 - 0s - loss: 0.3216 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 104/200
# 1/1 - 0s - loss: 0.3163 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 105/200
# 1/1 - 0s - loss: 0.3112 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 106/200
# 1/1 - 0s - loss: 0.3061 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 107/200
# 1/1 - 0s - loss: 0.3009 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 108/200
# 1/1 - 0s - loss: 0.2957 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 109/200
# 1/1 - 0s - loss: 0.2904 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 110/200
# 1/1 - 0s - loss: 0.2852 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 111/200
# 1/1 - 0s - loss: 0.2800 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 112/200
# 1/1 - 0s - loss: 0.2748 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 113/200
# 1/1 - 0s - loss: 0.2695 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 114/200
# 1/1 - 0s - loss: 0.2644 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 115/200
# 1/1 - 0s - loss: 0.2594 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 116/200
# 1/1 - 0s - loss: 0.2544 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 117/200
# 1/1 - 0s - loss: 0.2494 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 118/200
# 1/1 - 0s - loss: 0.2444 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 119/200
# 1/1 - 0s - loss: 0.2395 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 120/200
# 1/1 - 0s - loss: 0.2347 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 121/200
# 1/1 - 0s - loss: 0.2299 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 122/200
# 1/1 - 0s - loss: 0.2251 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 123/200
# 1/1 - 0s - loss: 0.2205 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 124/200
# 1/1 - 0s - loss: 0.2160 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 125/200
# 1/1 - 0s - loss: 0.2115 - binary_accuracy: 1.0000 - 233us/epoch - 233us/step
# Epoch 126/200
# 1/1 - 0s - loss: 0.2070 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 127/200
# 1/1 - 0s - loss: 0.2025 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 128/200
# 1/1 - 0s - loss: 0.1982 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 129/200
# 1/1 - 0s - loss: 0.1940 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 130/200
# 1/1 - 0s - loss: 0.1898 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 131/200
# 1/1 - 0s - loss: 0.1857 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 132/200
# 1/1 - 0s - loss: 0.1817 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 133/200
# 1/1 - 0s - loss: 0.1778 - binary_accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 134/200
# 1/1 - 0s - loss: 0.1739 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 135/200
# 1/1 - 0s - loss: 0.1700 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 136/200
# 1/1 - 0s - loss: 0.1662 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 137/200
# 1/1 - 0s - loss: 0.1626 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 138/200
# 1/1 - 0s - loss: 0.1591 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 139/200
# 1/1 - 0s - loss: 0.1555 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 140/200
# 1/1 - 0s - loss: 0.1521 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 141/200
# 1/1 - 0s - loss: 0.1486 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 142/200
# 1/1 - 0s - loss: 0.1453 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 143/200
# 1/1 - 0s - loss: 0.1421 - binary_accuracy: 1.0000 - 19ms/epoch - 19ms/step
# Epoch 144/200
# 1/1 - 0s - loss: 0.1390 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 145/200
# 1/1 - 0s - loss: 0.1359 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 146/200
# 1/1 - 0s - loss: 0.1328 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 147/200
# 1/1 - 0s - loss: 0.1298 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 148/200
# 1/1 - 0s - loss: 0.1269 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 149/200
# 1/1 - 0s - loss: 0.1240 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 150/200
# 1/1 - 0s - loss: 0.1213 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 151/200
# 1/1 - 0s - loss: 0.1186 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 152/200
# 1/1 - 0s - loss: 0.1160 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 153/200
# 1/1 - 0s - loss: 0.1133 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 154/200
# 1/1 - 0s - loss: 0.1108 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 155/200
# 1/1 - 0s - loss: 0.1084 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 156/200
# 1/1 - 0s - loss: 0.1059 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 157/200
# 1/1 - 0s - loss: 0.1036 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 158/200
# 1/1 - 0s - loss: 0.1013 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 159/200
# 1/1 - 0s - loss: 0.0991 - binary_accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 160/200
# 1/1 - 0s - loss: 0.0969 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 161/200
# 1/1 - 0s - loss: 0.0948 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 162/200
# 1/1 - 0s - loss: 0.0927 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 163/200
# 1/1 - 0s - loss: 0.0907 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 164/200
# 1/1 - 0s - loss: 0.0887 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 165/200
# 1/1 - 0s - loss: 0.0868 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 166/200
# 1/1 - 0s - loss: 0.0849 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 167/200
# 1/1 - 0s - loss: 0.0831 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 168/200
# 1/1 - 0s - loss: 0.0813 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 169/200
# 1/1 - 0s - loss: 0.0796 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 170/200
# 1/1 - 0s - loss: 0.0779 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 171/200
# 1/1 - 0s - loss: 0.0763 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 172/200
# 1/1 - 0s - loss: 0.0747 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 173/200
# 1/1 - 0s - loss: 0.0731 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 174/200
# 1/1 - 0s - loss: 0.0715 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 175/200
# 1/1 - 0s - loss: 0.0701 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 176/200
# 1/1 - 0s - loss: 0.0686 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 177/200
# 1/1 - 0s - loss: 0.0673 - binary_accuracy: 1.0000 - 8ms/epoch - 8ms/step
# Epoch 178/200
# 1/1 - 0s - loss: 0.0659 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 179/200
# 1/1 - 0s - loss: 0.0646 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 180/200
# 1/1 - 0s - loss: 0.0632 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 181/200
# 1/1 - 0s - loss: 0.0619 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 182/200
# 1/1 - 0s - loss: 0.0607 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 183/200
# 1/1 - 0s - loss: 0.0595 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 184/200
# 1/1 - 0s - loss: 0.0584 - binary_accuracy: 1.0000 - 14ms/epoch - 14ms/step
# Epoch 185/200
# 1/1 - 0s - loss: 0.0572 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 186/200
# 1/1 - 0s - loss: 0.0561 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 187/200
# 1/1 - 0s - loss: 0.0550 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 188/200
# 1/1 - 0s - loss: 0.0539 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 189/200
# 1/1 - 0s - loss: 0.0529 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 190/200
# 1/1 - 0s - loss: 0.0519 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 191/200
# 1/1 - 0s - loss: 0.0509 - binary_accuracy: 1.0000 - 15ms/epoch - 15ms/step
# Epoch 192/200
# 1/1 - 0s - loss: 0.0499 - binary_accuracy: 1.0000 - 11ms/epoch - 11ms/step
# Epoch 193/200
# 1/1 - 0s - loss: 0.0490 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# Epoch 194/200
# 1/1 - 0s - loss: 0.0481 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 195/200
# 1/1 - 0s - loss: 0.0472 - binary_accuracy: 1.0000 - 16ms/epoch - 16ms/step
# Epoch 196/200
# 1/1 - 0s - loss: 0.0464 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 197/200
# 1/1 - 0s - loss: 0.0455 - binary_accuracy: 1.0000 - 0s/epoch - 0s/step
# Epoch 198/200
# 1/1 - 0s - loss: 0.0447 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 199/200
# 1/1 - 0s - loss: 0.0439 - binary_accuracy: 1.0000 - 12ms/epoch - 12ms/step
# Epoch 200/200
# 1/1 - 0s - loss: 0.0431 - binary_accuracy: 1.0000 - 1ms/epoch - 1ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x000001F44E25C670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0424 - binary_accuracy: 1.0000
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001F44E25CB80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 56ms/step
# array([[0.]], dtype=float32)
