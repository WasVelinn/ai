# %% [markdown]
# 전국 평균 평당 분양가격(2013년 9월부터 2015년 8월까지).csv (지역명, 평당분양가격, 연도, 월)
# - 지역명2 : 지역명필드는 라벨인코딩하여 추가
# - 평당분양가격n : 평당분양가격의 정규화 스케일 조정하여 추가
# - 평당분양가격s : 평당분양가격의 표준화 스케일 조정하여 추가
# - 연도n : 연도의 정규화 스케일 조정하여 추가
# - 연도s : 연도의 표준화 스케일 조정하여 추가
# - 월n : 월의 정규화 스케일 조정하여 추가
# - 월s : 월의 표준화 스케일 조정하여 추가

# %%
import pandas as pd

df = pd.read_csv(r'D:\STUDENTS\KIMCHEOLMIN\ai\Downloads\shareData\전국 평균 평당 분양가격(2013년 9월부터 2015년 8월까지).csv', encoding='cp949')
df
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0   서울     18189    17925    17925    18016    18098    19446    18867
# 1   부산      8111     8111     9078     8965     9402     9501     9453
# 2   대구      8080     8080     8077     8101     8267     8274     8360
# 3   인천     10204    10204    10408    10408    10000     9844    10058
# 4   광주      6098     7326     7611     7346     7346     7523     7659
# 5   대전      8321     8321     8321     8341     8341     8341     8333
# 6   울산      8090     8090     8090     8153     8153     8153     8153
# 7   경기     10855    10855    10791    10784    10876    10646    10266
# 8   세종      7601     7600     7532     7814     7908     7934     8067
# 9   강원      6230     6230     6230     6141     6373     6350     6350
# 10  충북      6589     6589     6611     6625     6678     6598     6587
# 11  충남      6365     6365     6379     6287     6552     6591     6644
# ...

# %%
df_melted = df.melt(id_vars=['지역'])

# %%
df_melted['평당분양가격'] = df_melted['value']

# %%
def month(row):
    result = row.split('년')
    return result[0] + '년'

# %%
df_melted['연도'] = df_melted['variable'].apply(month)

# %%
df_melted['월'] = df_melted['variable'].apply(lambda x : x.split('년')[1])

# %%
df_melted.drop(columns=['variable', 'value'], inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
labeling_data = le.fit_transform(df_melted['지역'])

# %%
df_melted['지역명2'] = labeling_data

# %%
df_melted
# Out:
#      지역  평당분양가격     연도    월  지역명2
# 0    서울   18189  2013년  12월     8
# 1    부산    8111  2013년  12월     7
# 2    대구    8080  2013년  12월     5
# 3    인천   10204  2013년  12월    11
# 4    광주    6098  2013년  12월     4
# ..   ..     ...    ...  ...   ...
# 352  전북    6580  2015년   8월    13
# 353  전남    6289  2015년   8월    12
# 354  경북    7037  2015년   8월     3
# 355  경남    7665  2015년   8월     2
# 356  제주    7343  2015년   8월    14
#
# [357 rows x 5 columns]

# %%
# - 평당분양가격n : 평당분양가격의 정규화 스케일 조정하여 추가

from sklearn.preprocessing import MinMaxScaler
sc_s = MinMaxScaler() # x_data를 표준화 시킬 객체
sc_s.fit(s.reshape(-1,1))
sc_s_data = sc_s.transform(s.reshape(-1,1))

# %%
# - 평당분양가격s : 평당분양가격의 표준화 스케일 조정하여 추가

# %%
import numpy as np
s = np.array(df_melted['평당분양가격'])

# %%
df_melted['평당분양가격n'] = sc_s_data.reshape(1, len(sc_s_data))[0]

# %%
sc_s_data
# Out:
# array([[0.8352699 ],
#        [0.16612443],
#        [0.16406613],
#        [0.30509262],
#        [0.03246796],
#        [0.18006772],
#        [0.1647301 ],
#        [0.34831684],
#        [0.13226213],
#        [0.04123232],
#        [0.06506872],
#        [0.05019587],
#        [0.04468495],
#        [0.00458137],
#        [0.03711573],
#        [0.05736671],
#        [0.13710909],
#        [0.81774119],
#        [0.16612443],
#        [0.16406613],
#        [0.30509262],
#        [0.11400305],
#        [0.18006772],
#        [0.1647301 ],
#        [0.34831684],
#        [0.13219574],
#        [0.04123232],
#        [0.06506872],
#        [0.05019587],
#        [0.04461855],
#        [0.00458137],
#        [0.03711573],
#        [0.05816347],
#        [0.15211473],
#        [0.81774119],
#        [0.23032999],
#        [0.16386694],
#        [0.31863754],
#        [0.1329261 ],
#        [0.18006772],
#        [0.1647301 ],
#        [0.34406746],
#        [0.12768076],
# ...
