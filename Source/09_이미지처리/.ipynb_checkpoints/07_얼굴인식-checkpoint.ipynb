# %%
# 얼굴인식(얼굴정보) 세로*가로*3 넘파이 -> 1*512(임베딩데이터로 변환) -> X, y를 머신러닝(SVM)

# %% [markdown]
# # 1. 데이터 셋 다운로드 및 압축해제
# https://www.kaggle.com/datasets/dansbecker/5-celebrity-faces-dataset?resource=download

# %%
# !unzip data/5celebrity.zip -d data/5celebrity/

# %% [markdown]
# #

# %%
# ! pip install mtcnn

# %%
from mtcnn import MTCNN
import PIL
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## 2.1 MTCNN을 이용해서 얼굴 형태 탐지

# %%
detector = MTCNN()
image = cv2.imread('data/5celebrity/train/ben_afflek/httpcsvkmeuaeccjpg.jpg',
                   cv2.IMREAD_ANYCOLOR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
result = detector.detect_faces(image)
result
# Out:
# [{'box': [14, 30, 76, 92],
#   'confidence': 0.9998857975006104,
#   'keypoints': {'nose': [36, 91],
#    'mouth_right': [64, 98],
#    'right_eye': [51, 63],
#    'left_eye': [27, 75],
#    'mouth_left': [44, 109]}}]

# %% [markdown]
# ## 2.2 탐지한 얼굴 그려보기

# %%
box = result[0]['box'] # 왼쪽위부분의 x, y, width, height
x, y, w, h = box
keypoints = result[0]['keypoints'] # nose, mouth_right, right_eye, left_eye, mouth_left
cv2.rectangle(image,
              (x, y), # 사각형 왼쪽 윗부분 좌표
              (x+w, y+h), # 사각형 오른쪽 밑부분 좌표
              (0, 155, 255),
              2
              )
cv2.circle(image, keypoints['nose'], # 원의 중심점
           2, # 반지름
           (255,0,0), # 원 색상
           )
cv2.circle(image, keypoints['mouth_right'], # 원의 중심점
           2, # 반지름
           (255,0,0), # 원 색상
           )
cv2.circle(image, keypoints['right_eye'], # 원의 중심점
           2, # 반지름
           (255,0,0), # 원 색상
           )
cv2.circle(image, keypoints['left_eye'], # 원의 중심점
           2, # 반지름
           (255,0,0), # 원 색상
           )
cv2.circle(image, keypoints['mouth_left'], # 원의 중심점
           2, # 반지름
           (255,0,0), # 원 색상
           )
cv2.imwrite('data/ben.jpg', cv2.cvtColor(image, cv2.COLOR_RGB2BGR))

face = image[y:y+h, x:x+w]
cv2.imwrite('data/benface.jpg', cv2.cvtColor(face, cv2.COLOR_RGB2BGR))
# Out:
# True

# %%
fig, axes = plt.subplots(1, 2, figsize=(5,3))
axes[0].imshow(image)
axes[0].axis('off')
axes[1].imshow(face)
axes[1].axis('off')
plt.show()

# %%
image = cv2.imread('data/5celebrity/train/elton_john/12.jpg',
                   cv2.IMREAD_ANYCOLOR)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
result = detector.detect_faces(image)

box = result[0]['box'] # 왼쪽위부분의 x, y, width, height
x, y, w, h = box
keypoints = result[0]['keypoints'] # nose, mouth_right, right_eye, left_eye, mouth_left
cv2.rectangle(image,
              (x, y), # 사각형 왼쪽 윗부분 좌표
              (x+w, y+h), # 사각형 오른쪽 밑부분 좌표
              (0, 155, 255),
              2
              )
cv2.circle(image, keypoints['nose'], # 원의 중심점
           2, # 반지름
           (255,0,0), # 원 색상
           )
cv2.circle(image, keypoints['mouth_right'], # 원의 중심점
           2, # 반지름
           (255,0,0), # 원 색상
           )
cv2.circle(image, keypoints['right_eye'], # 원의 중심점
           2, # 반지름
           (255,0,0), # 원 색상
           )
cv2.circle(image, keypoints['left_eye'], # 원의 중심점
           2, # 반지름
           (255,0,0), # 원 색상
           )
cv2.circle(image, keypoints['mouth_left'], # 원의 중심점
           2, # 반지름
           (255,0,0), # 원 색상
           )
face = image[y:y+h, x:x+w]
fig, axes = plt.subplots(1, 2, figsize=(5,3))
axes[0].imshow(image)
axes[0].axis('off')
axes[1].imshow(face)
axes[1].axis('off')
plt.show()

# %% [markdown]
# ## 2.3 입력형식에 맞게 차원 변환

# %%
face.shape
# Out:
# (83, 66, 3)

# %%
face_data = np.expand_dims(face, axis=0)
# face_data = face.reshape(-1, face.shape[0],face.shape[1],face.shape[2]) 비추
face_data = face[np.newaxis, :]
face_data.shape
# Out:
# (1, 83, 66, 3)

# %% [markdown]
# # 3. Facenet 활용하여 임베딩 데이터로 변환(face_data를)
# - face_data = 1x83x66x3
# - 임베딩 데이터 : 1x512

# %%
# pip install keras-facenet

# %%
from keras_facenet import FaceNet
model = FaceNet()

# %% [markdown]
# ## 3-1 이미지 데이터를 FaceNet 임베딩 데이터로 변환

# %%
# face_data 얼굴 이미지이거나 얼굴 특징 데이터가 있는 이미지를 유사성을 측정할 수 있는 1x512 배열로 변환
face_embedding = model.embeddings(face_data)
face_embedding.shape

# %%
face_embedding

# %%
face_embedding[0, :10]

# %% [markdown]
# # 4. 분류모델을 만들기 위해 데이터셋 생성
# - X_train(n x 512), y_train(n) * n은 train 폴더안의 사진 갯수
# - X_test(m x 512), y_test(m) * m은 test 폴더안의 사진 갯수
# ## 4.1 y_train(사람이름)과 X_train에 사용될 이미지 경로(x_train_path)
# - y_test(사람이름)과 X_test에 사용될 이미지 경로(x_test_path)

# %%
import os
train_path = 'data/5celebrity/train'
test_path = 'data/5celebrity/val'

# %%
list(os.walk(train_path))

# %%
for x in os.walk(train_path):
    print(x)
    print('----------------------------------')

# %%
def get_path(path):
    x_path = []
    y = []
    for x in os.walk(path):
        if len(x[2])==0:
            # print(x, '에는 파일이 없습니다.')
            continue
        name = os.path.basename(x[0])
        for file_name in x[2]:
            # image_full_path = x[0].replace(r'\','/') + '/' + file_name
            image_full_path = path + '/' + name + '/' + file_name
            x_path.append(image_full_path)
            y.append(name)
#         print(len(y))
#         print(len(x_path))
#     for name, path in zip(y, x_path):
#         print(name, path)
    return x_path, y

# %%
# get_path(train_path)
x_train_path, y_train = get_path(train_path)
x_test_path, y_test = get_path(test_path)

# %%
len(x_train_path), len(y_train), len(x_test_path), len(y_test)

# %%
for y, x in zip(y_train[::10], x_train_path[::10]):
    print(y, '-', x)

# %%
for y, x in zip(y_test[::10], x_test_path[::10]):
    print(y, '-', x)

# %% [markdown]
# ## 4-2 임베딩함수를 통해 전체 학습 이미지를 임베딩 처리한 후 train_X리스트에 저장

# %%
def make_embedding(path):
    'path의 이미지 읽기 -> 얼굴정보만 추출 -> facenet을 통해 임베딩 데이터로 전환'
    # print(path)
    image = cv2.imread(path, cv2.IMREAD_ANYCOLOR) # BGR 포맷
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # RGB 포맷
    result = detector.detect_faces(image)
    if not result:
        print(path, '의 파일에서 얼굴을 인지하지 못했습니다.')
    # print(result)
    x, y, w, h = result[0]['box']
    face = image[y:y+h, x:x+w]
    # face 데이터 축 추가
    input_data = np.expand_dims(face, axis=0)
    # 임베딩 데이터로 전환
    face_embedding = model.embeddings(input_data)
    return face_embedding

# %%
X_train_list = []
for image_full_path in x_train_path:
    face_embedding = make_embedding(image_full_path)
    X_train_list.append(face_embedding[0])
# Out:
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 55ms/step

# %%
X_train_list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 X_train_list.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
X_test_list = []
for image_full_path in x_test_path:
    face_embedding = make_embedding(image_full_path)
    X_test_list.append(face_embedding[0])
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
len(X_train_list), len(y_train)
# Out:
# (92, 92)

# %%
X_train = np.array(X_train_list)
X_test = np.array(X_test_list)

# %% [markdown]
# # 5. SVM(Support Vector Machine) 알고리즘을 이용하여 모델 생성

# %%
from sklearn import preprocessing, svm
from sklearn.metrics import accuracy_score, confusion_matrix
import pandas as pd

classifier = svm.SVC(kernel='linear', probability=True) # 확률값 반환
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', probability=True)

# %%
y_hat = classifier.predict(X_test) # X_test의 예측값
accuracy = accuracy_score(y_test, # 실제값
                          y_hat) # 예측값
print(accuracy*100, '%')
# Out:
# 100.0 %

# %%
confusion_matrix(y_test, y_hat) # 혼돈행렬
# Out:
# array([[5, 0, 0, 0, 0],
#        [0, 5, 0, 0, 0],
#        [0, 0, 5, 0, 0],
#        [0, 0, 0, 5, 0],
#        [0, 0, 0, 0, 5]], dtype=int64)

# %%
pd.crosstab(y_test, y_hat)
# Out:
# col_0           ben_afflek  elton_john  jerry_seinfeld  madonna  mindy_kaling
# row_0
# ben_afflek               5           0               0        0             0
# elton_john               0           5               0        0             0
# jerry_seinfeld           0           0               5        0             0
# madonna                  0           0               0        5             0
# mindy_kaling             0           0               0        0             5

# %% [markdown]
# # 6. 생성된 모델 사용(예측)하기

# %%
image_path = 'data/test_elton.jpg'
face_embedding = make_embedding(image_path)
classifier.predict(face_embedding)
# Out:
# 1/1 [==============================] - 0s 38ms/step
# array(['elton_john'], dtype='<U14')

# %%
image_path = 'data/test_madonna.jpg'
face_embedding = make_embedding(image_path)
classifier.predict(face_embedding)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# array(['madonna'], dtype='<U14')

# %% [markdown]
# # 7. 모델 저장

# %%
# SVC 모델은 h5파일로 저장 안 됨
import joblib
joblib.dump(classifier, 'model/face_svc.pkl')
# Out:
# ['model/face_svc.pkl']

# %% [markdown]
# # 8. 모델 불러오기

# %%
loaded_model = joblib.load('model/face_svc.pkl')

# %%
image_path = 'data/test_madonna.jpg'
face_embedding = make_embedding(image_path)
print(loaded_model.predict(face_embedding))
print(loaded_model.predict_proba(face_embedding))
image = cv2.imread(image_path)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# ['madonna']
# [[0.05656151 0.04492513 0.04703086 0.7075701  0.14391241]]
